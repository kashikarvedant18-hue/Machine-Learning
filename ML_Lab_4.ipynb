# %% [markdown]
# # Machine Learning - Lab 4

# %% [markdown]
# ### Name : Vedant Kashikar
# ### Class : A-A1-4

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv('WineQT.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 1. Univariate Analysis

# %%
import matplotlib.pyplot as plt
numeric_cols=df.columns
for col in numeric_cols:
    plt.figure(figsize=(7,4))
    sns.histplot(df[col],kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(7,3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of{col}')
    plt.show()

# %%
df.describe().T
# Out:
#                        count        mean         std      min        25%  \
# fixed acidity         1143.0    8.311111    1.747595  4.60000    7.10000
# volatile acidity      1143.0    0.531339    0.179633  0.12000    0.39250
# citric acid           1143.0    0.268364    0.196686  0.00000    0.09000
# residual sugar        1143.0    2.532152    1.355917  0.90000    1.90000
# chlorides             1143.0    0.086933    0.047267  0.01200    0.07000
# free sulfur dioxide   1143.0   15.615486   10.250486  1.00000    7.00000
# total sulfur dioxide  1143.0   45.914698   32.782130  6.00000   21.00000
# density               1143.0    0.996730    0.001925  0.99007    0.99557
# pH                    1143.0    3.311015    0.156664  2.74000    3.20500
# sulphates             1143.0    0.657708    0.170399  0.33000    0.55000
# alcohol               1143.0   10.442111    1.082196  8.40000    9.50000
# quality               1143.0    5.657043    0.805824  3.00000    5.00000
# Id                    1143.0  804.969379  463.997116  0.00000  411.00000
#
#                             50%          75%         max
# fixed acidity           7.90000     9.100000    15.90000
# volatile acidity        0.52000     0.640000     1.58000
# citric acid             0.25000     0.420000     1.00000
# residual sugar          2.20000     2.600000    15.50000
# chlorides               0.07900     0.090000     0.61100
# free sulfur dioxide    13.00000    21.000000    68.00000
# total sulfur dioxide   37.00000    61.000000   289.00000
# density                 0.99668     0.997845     1.00369
# pH                      3.31000     3.400000     4.01000
# sulphates               0.62000     0.730000     2.00000
# alcohol                10.20000    11.100000    14.90000
# quality                 6.00000     6.000000     8.00000
# Id                    794.00000  1209.500000  1597.00000

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='quality',data=df)
plt.title('Distribution of Wine quality')
plt.show()

# %%
df['quality'].value_counts().sort_index()
# Out:
# quality
# 3      6
# 4     33
# 5    483
# 6    462
# 7    143
# 8     16
# Name: count, dtype: int64

# %%
features=df.drop(columns=['quality'])
Q1=features.quantile(0.25)
Q3=features.quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outlier_mask=(features<lower_bound)|(features>upper_bound)
outlier_count=outlier_mask.sum()
outlier_percentage=(outlier_count/len(features))*100
outlier_summary=pd.DataFrame({
    'Q1':Q1,
    'Q3':Q3,
    'IQR':IQR,
    'Lower Bound':lower_bound,
    'Upper Bound':upper_bound,
    'Outlier Count':outlier_count,
    'Outlier%':outlier_percentage
})

outlier_summary.round(5)
# Out:
#                              Q1          Q3        IQR  Lower Bound  \
# fixed acidity           7.10000     9.10000    2.00000      4.10000
# volatile acidity        0.39250     0.64000    0.24750      0.02125
# citric acid             0.09000     0.42000    0.33000     -0.40500
# residual sugar          1.90000     2.60000    0.70000      0.85000
# chlorides               0.07000     0.09000    0.02000      0.04000
# free sulfur dioxide     7.00000    21.00000   14.00000    -14.00000
# total sulfur dioxide   21.00000    61.00000   40.00000    -39.00000
# density                 0.99557     0.99784    0.00228      0.99216
# pH                      3.20500     3.40000    0.19500      2.91250
# sulphates               0.55000     0.73000    0.18000      0.28000
# alcohol                 9.50000    11.10000    1.60000      7.10000
# Id                    411.00000  1209.50000  798.50000   -786.75000
#
#                       Upper Bound  Outlier Count  Outlier%
# fixed acidity            12.10000             44   3.84952
# volatile acidity          1.01125             14   1.22485
# citric acid               0.91500              1   0.08749
# residual sugar            3.65000            110   9.62380
# chlorides                 0.12000             77   6.73666
# free sulfur dioxide      42.00000             18   1.57480
# total sulfur dioxide    121.00000             40   3.49956
# density                   1.00126             36   3.14961
# pH                        3.69250             20   1.74978
# sulphates                 1.00000             43   3.76203
# alcohol                  13.50000             12   1.04987
# Id                     2407.25000              0   0.00000

# %%
plt.figure(figsize=(12,6))

outlier_count.sort_values(ascending=False).plot(kind='bar')

plt.title("Number of Outlier in each features")
plt.xlabel("Features")
plt.ylabel("Number of Outliers")
plt.xticks(rotation=45,ha="right")
plt.grid(axis='y',alpha=0.3)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='quality',data=df)
plt.title('Distribution of Wine Quality')
plt.show()

# %%
df['quality'].value_counts().sort_index()
# Out:
# quality
# 3      6
# 4     33
# 5    483
# 6    462
# 7    143
# 8     16
# Name: count, dtype: int64

# %% [markdown]
# # 2. Bivariate Analysis

# %%
sns.boxplot(x='quality',y='alcohol',data=df)
plt.title('Alcohol vs Wine Quality')
plt.show()

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
features=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality', 'Id']
for col in features:
    plt.figure(figsize=(7,4))
    sns.boxplot(x='quality',y=col,data=df)
    plt.title(f'{col} vs Wine Quality')
    plt.show()

# %%
#Scatter Plot

sns.scatterplot(x='alcohol',y='quality',data=df)
plt.title('Alcohol Vs Quality')
plt.show()

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)
plt.title('Volatile Acidity vs Quality')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(12,8))
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f')

plt.title("Correlation Heatmap")
plt.show()

# %%
#Pair Plot
selected=['alcohol','volatile acidity','sulphates','citric acid','quality']

sns.pairplot(df[selected],hue='quality')
plt.show()

# %%
df['quality_group']=pd.cut(
    df['quality'],
    bins=[0,5,6,10],
    labels=['low','medium','high']
)

# %%
sns.boxplot(
    x='quality_group',y='alcohol',data=df)

plt.title('Alcohol Distribution Across Quality Groups')
plt.show()

# %%
sns.countplot(
    x='quality_group',data=df)

plt.title('Alcohol Distribution Across Quality Groups')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix,ConfusionMatrixDisplay)

# %%
X=df.drop('quality',axis=1)
y=df['quality']

# %%
print("X shape:",X.shape)
print("y shape:",y.shape)
# Out:
# X shape: (1143, 13)
# y shape: (1143,)

# %%
print(y.value_counts().sort_index())
# Out:
# quality
# 3      6
# 4     33
# 5    483
# 6    462
# 7    143
# 8     16
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.20,random_state=42,stratify=y)

# %%
criterion='entropy'

# %%
dt_model=DecisionTreeClassifier(criterion='entropy',random_state=42)

# %%
df['quality_group']=pd.cut(
    df['quality'],
    bins=[0,5,6,10],
    labels=['Low','Medium','High']
)

# %%
print(X.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'Id', 'quality_group'],
#       dtype='str')

# %%
print(X.select_dtypes(exclude='number').columns)
# Out:
# Index(['quality_group'], dtype='str')

# %%
y=df['quality']

# %%
X=df.drop(columns=['quality','quality_groups'], errors='ignore')

# %%
print(X.columns)
print(X.dtypes)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'Id', 'quality_group'],
#       dtype='str')
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# Id                         int64
# quality_group           category
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.20,random_state=42,stratify=y)

# %%
print("X_train:",X_train.shape)
print("X_test:",X_test.shape)
print("y_train:",X_train.shape)
print("y_test:",X_test.shape)
# Out:
# X_train: (914, 13)
# X_test: (229, 13)
# y_train: (914, 13)
# y_test: (229, 13)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (914, 13)
# (914,)

# %%
X_train['quality_group'] = X_train['quality_group'].astype(int)
X_test['quality_group'] = X_test['quality_group'].astype(int)

print(X_train['quality_group'].dtype)
# Out:
# int64

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier(criterion='entropy',random_state=42)

dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
y_train_pred=dt_model.predict(X_train)
y_test_pred=dt_model.predict(X_test)

# %%
train_accuracy=accuracy_score(y_train,y_train_pred)
print("Training Accuracy:",train_accuracy)
# Out:
# Training Accuracy: 1.0

# %%
test_accuracy=accuracy_score(y_train,y_train_pred)
print("Test Accuracy:",test_accuracy)
# Out:
# Test Accuracy: 1.0

# %%
print("Precision:", precision_score(y_test,y_test_pred,average="weighted"))

print("Recall",recall_score(y_test,y_test_pred,average='weighted'))

print("F1 Score:",f1_score(y_test,y_test_pred,average='weighted'))
# Out:
# Precision: 0.9140278366023572
# Recall 0.8995633187772926
# F1 Score: 0.9061899788492934
# /Users/nidhiii/venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.08      0.14      0.10         7
#            5       0.93      0.89      0.91        97
#            6       1.00      1.00      1.00        92
#            7       0.90      0.93      0.92        29
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.90       229
#    macro avg       0.49      0.49      0.49       229
# weighted avg       0.91      0.90      0.91       229
# /Users/nidhiii/venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/nidhiii/venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/nidhiii/venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#Confusion Matrix

cm=confusion_matrix(y_test,y_test_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm,annot=True,fmt='d',cmap= 'Blues',cbar=False)

plt.xlabel('Predicted Quality')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
print("Tree Depth:",dt_model.get_depth())
print("Number of Leaves:",dt_model.get_n_leaves())
# Out:
# Tree Depth: 10
# Number of Leaves: 50

# %%
plt.figure(figsize=(25,15))

plot_tree(dt_model,features_names=X.columns,class_name=[str(c) for c in sorted (y.unique(0)],filled=True,rounded=True,fontsize=8)

plt.title("Decision Tree - Entropy")
plt.show()
# Out:
#   Cell In[184], line 3
#     plot_tree(dt_model,features_names=X.columns,class_name=[str(c) for c in sorted (y.unique(0)],filled=True,rounded=True,fontsize=8)
#                                                                                                ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
